# %% [markdown]
# ## Week 1 – Monthly Dataset Aggregation
# Individual monthly files are combined into unified datasets that span multiple months, enabling trend
# analysis over time.

# %% [markdown]
# ### Objective
# Load and concatenate all monthly MLS files from January 2024 through the most recently completed
# calendar month into analysis-ready combined datasets.
#
# ### Outputs
# - Combined sold transactions dataset
# - Combined listing data dataset
#
# ### Skills Learned
# - Multi-file dataset management
# - Data aggregation with Pandas
# - Preparing time-series datasets for analysis

# %%
# This line just hides warning messages so we can focus on the results—but we only use it when we understand what those warnings mean.
import warnings
warnings.filterwarnings("ignore")

# Libraries to help with reading and manipulating data
import pandas as pd
import numpy as np
import glob
from pathlib import Path
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = Path("/Users/sarahbarah3/Desktop/crmls")
save_path = Path("/Users/sarahbarah3/Desktop/crmls/combined")

# %%
def read_csv_with_fallback(filepath):
    """Read CSV with UTF-8, fallback to cp1252 if needed."""
    try:
        df = pd.read_csv(filepath, encoding="utf-8")
        return df, "utf-8"
    except UnicodeDecodeError:
        df = pd.read_csv(filepath, encoding="cp1252")
        return df, "cp1252"

# %% [markdown]
# ### Define lists

# %%
listing_files = list(data_path.glob("CRMLSListing*.csv"))
sold_files = list(data_path.glob("CRMLSSold*.csv"))

# %%
print(list(data_path.glob("*.csv")))
# Out:
# [PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202404_filled.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202409.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202405.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202411.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202410.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202404.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202408.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202412.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202406.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202407.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/priceratio.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202501_filled.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202601.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202403.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202402.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202602.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202401_filled.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202401.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202603.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202512.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202506.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202406_filled.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202507.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202505.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202511.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202509.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202508.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202510.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202504.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202501.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202503.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202502.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202403_filled.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202503.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202502.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202405_filled.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202509.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202505.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202511.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202510.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202504.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202508.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202512.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202506.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202507.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202602.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202603.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202401.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202403.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202601.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202402.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202412.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202407_filled.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202411.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202409.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/newlistings.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSListing202408.csv'), PosixPath('/Users/sarahbarah3/Desktop/crmls/CRMLSSold202410 ...

# %% [markdown]
# ### Read and Concateante

# %%
full_listing = []
encoding_log = []
row_counts = []

for filepath in listing_files:
    df, encoding_used = read_csv_with_fallback(filepath)

    full_listing.append(df)
    encoding_log.append((filepath, encoding_used))
    row_counts.append(len(df))

# Safety check before concat
if full_listing:
    listing_combined = pd.concat(full_listing, ignore_index=True)
    print("Combined listing shape:", listing_combined.shape)
else:
    print("No listing files were loaded.")
# Out:
# Combined listing shape: (851298, 84)

# %%
full_sold = []
encoding_log_sold = []
row_counts_sold = []

for filepath in sold_files:
    df, encoding_used = read_csv_with_fallback(filepath)

    full_sold.append(df)
    encoding_log_sold.append((filepath, encoding_used))
    row_counts_sold.append(len(df))

if full_sold:
    sold_combined = pd.concat(full_sold, ignore_index=True)
    print("Combined sold shape:", sold_combined.shape)
else:
    print("No sold files were loaded.")
# Out:
# Combined sold shape: (658362, 84)

# %%
listing_combined.to_csv(save_path / "listing_combined.csv", index=False)
sold_combined.to_csv(save_path / "sold_combined.csv", index=False)

# %% [markdown]
# ### View the first and last 5 rows of the listing dataset.

# %%
listing_combined.head()
# Out:
#    OriginalListPrice  ListingKey                       ListAgentEmail  \
# 0           929000.0  1076194146                   dianne@drector.com
# 1           999999.0  1076194026  realestateby_denisegarcia@gmail.com
# 2          1400000.0  1076193814           alizabethjames@hotmail.com
# 3          4998888.0  1076193812               ernieramos62@yahoo.com
# 4           549000.0  1076193525                  parsanina@yahoo.com
#
#   CloseDate  ClosePrice ListAgentFirstName ListAgentLastName   Latitude  \
# 0       NaN         NaN             Dianne            Rector        NaN
# 1       NaN         NaN             Denise            Garcia        NaN
# 2       NaN         NaN          Alizabeth             James  33.858559
# 3       NaN         NaN            Ernesto             Ramos        NaN
# 4       NaN         NaN               Nina             Parsa        NaN
#
#     Longitude         UnparsedAddress  ... GarageSpaces  \
# 0         NaN       16882 Canyon Lane  ...          2.0
# 1         NaN       8720 S 4th Avenue  ...          2.0
# 2 -116.542169       505 E Molino Road  ...          2.0
# 3         NaN    3653 Halldale Avenue  ...          0.0
# 4         NaN  1736 N Mcdivitt Avenue  ...          2.0
#
#             HighSchoolDistrict  PostalCode  BuyerOfficeName.1 AssociationFee  \
# 0  Huntington Beach Union High       92649                NaN          330.0
# 1            Inglewood Unified       90305                NaN            0.0
# 2         Palm Springs Unified       92262                NaN            NaN
# 3                          NaN       90018                NaN            NaN
# 4          Los Angeles Unified       90221                NaN            0.0
#
#   LotSizeSquareFeet MiddleOrJuniorSchoolDistrict       UnparsedAddress.1  \
# 0            1847.0                          NaN       16882 Canyon Lane
# 1            8508.0                          NaN       8720 S 4th Avenue
# 2           10890.0                          NaN       505 E Molino Road
# 3            6192.0                          NaN    3653 Halldale Avenue
# 4            4113.0                          NaN  1736 N Mcdivitt Avenue
#
#   BuyerAgencyCompensationType BuyerAgencyCompensation
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
#
# [5 rows x 84 columns]

# %%
listing_combined.tail()
# Out:
#         OriginalListPrice  ListingKey              ListAgentEmail CloseDate  \
# 851293            25000.0  1061308992         robin@cbborrego.com       NaN
# 851294           625000.0  1060129455         joel@ripfritzer.com       NaN
# 851295           409000.0  1058408504  marierealtor4you@gmail.com       NaN
# 851296          3900000.0  1038675566         brettbman@gmail.com       NaN
# 851297          1825000.0  1038248402      taylor@willisallen.com       NaN
#
#         ClosePrice ListAgentFirstName ListAgentLastName   Latitude  \
# 851293         NaN              Robin          Reynolds  33.273002
# 851294         NaN               Joel             Cloud  32.773679
# 851295         NaN              Marie         Arredondo  33.207200
# 851296         NaN              Brett           Baumann  37.497693
# 851297         NaN             Taylor             Smith  32.617947
#
#          Longitude                     UnparsedAddress  ... GarageSpaces  \
# 851293 -115.953189                1102 Stanford Avenue  ...          NaN
# 851294 -116.933649                     1725 Grove Road  ...          NaN
# 851295 -116.299900               3135 Club Circle East  ...          2.0
# 851296 -120.046471  665 Acs. - Mt Bullion Cut-Off Road  ...          NaN
# 851297 -117.134345                   5 Bridgetown Bend  ...          2.0
#
#              HighSchoolDistrict  PostalCode  BuyerOfficeName.1 AssociationFee  \
# 851293                      NaN       92274                NaN            0.0
# 851294                      NaN       92020                NaN            0.0
# 851295  Borrego Springs Unified       92004                NaN            0.0
# 851296                      NaN       95338                NaN            0.0
# 851297         Coronado Unified       92118                NaN          331.0
#
#        LotSizeSquareFeet MiddleOrJuniorSchoolDistrict  \
# 851293           13503.6                          NaN
# 851294           43560.0                          NaN
# 851295           34848.0                          NaN
# 851296        28980903.6                          NaN
# 851297            3959.0                          NaN
#
#                          UnparsedAddress.1 BuyerAgencyCompensationType  \
# 851293                1102 Stanford Avenue                         NaN
# 851294                     1725 Grove Road                         NaN
# 851295               3135 Club Circle East                         NaN
# 851296  665 Acs. - Mt Bullion Cut-Off Road                         NaN
# 851297                   5 Bridgetown Bend                         NaN
#
#        BuyerAgencyCompensation
# 851293                     NaN
# 851294                     NaN
# 851295                     NaN
# 851296                     NaN
# 851297                     NaN
#
# [5 rows x 84 columns]

# %% [markdown]
# ### View the first and last 5 rows of the sold dataset.

# %%
sold_combined.head()
# Out:
#   Flooring ViewYN WaterfrontYN BasementYN PoolPrivateYN  OriginalListPrice  \
# 0      NaN   True          NaN        NaN           NaN           159000.0
# 1      NaN   True          NaN        NaN           NaN           144000.0
# 2      NaN   True          NaN        NaN         False           265000.0
# 3      NaN   True          NaN        NaN           NaN           925000.0
# 4      NaN   True          NaN        NaN           NaN            25000.0
#
#    ListingKey                       ListAgentEmail   CloseDate  ClosePrice  \
# 0   555125771  deborah.potestio@c21selectgroup.com  2024-04-29     45000.0
# 1   554271746              crchapman@sbcglobal.net  2024-04-26     78000.0
# 2   543251400        michaelg@londonproperties.com  2024-04-02    250000.0
# 3   539236677               chris.campbell@msn.com  2024-04-10    815000.0
# 4   538449222                rrinder@sbcglobal.net  2024-04-06     15000.0
#
#    ... PostalCode AssociationFee  LotSizeSquareFeet  \
# 0  ...      95916            0.0           336283.2
# 1  ...      95966            0.0           101495.0
# 2  ...      93726            0.0             8100.0
# 3  ...      92223            0.0           564988.0
# 4  ...      95966            0.0             6098.0
#
#    MiddleOrJuniorSchoolDistrict latfilled lonfilled  BuyerAgentAOR  \
# 0                           NaN     False     False            NaN
# 1                           NaN     False     False            NaN
# 2                           NaN     False     False            NaN
# 3                           NaN     False     False            NaN
# 4                           NaN     False     False            NaN
#
#    ListAgentAOR  OriginatingSystemName OriginatingSystemSubName
# 0           NaN                    NaN                      NaN
# 1           NaN                    NaN                      NaN
# 2           NaN                    NaN                      NaN
# 3           NaN                    NaN                      NaN
# 4           NaN                    NaN                      NaN
#
# [5 rows x 84 columns]

# %%
sold_combined.tail()
# Out:
#        Flooring ViewYN WaterfrontYN BasementYN PoolPrivateYN  \
# 658357      NaN    NaN          NaN        NaN           NaN
# 658358      NaN   True          NaN        NaN           NaN
# 658359      NaN   True          NaN        NaN           NaN
# 658360      NaN  False          NaN        NaN         False
# 658361      NaN   True          NaN        NaN           NaN
#
#         OriginalListPrice  ListingKey                        ListAgentEmail  \
# 658357           649000.0  1008475397              chiggamasta424@gmail.com
# 658358            75689.0  1003434877        jhisquierdo@lee-associates.com
# 658359           275000.0  1002713752                MLS@DaltonRealtors.com
# 658360            10000.0  1002447928  Tazzie@CoronadoPremierProperties.com
# 658361          1600000.0  1001660596                diana@countryqueen.com
#
#          CloseDate  ClosePrice  ... PostalCode AssociationFee  \
# 658357  2024-04-22    450000.0  ...      90805            NaN
# 658358  2024-04-03     75689.0  ...      92371            NaN
# 658359  2024-04-19    100000.0  ...      92082            0.0
# 658360  2024-04-05      8300.0  ...      92118            0.0
# 658361  2024-04-03   1050000.0  ...      91765          294.0
#
#         LotSizeSquareFeet  MiddleOrJuniorSchoolDistrict latfilled lonfilled  \
# 658357             4682.0                           NaN       NaN       NaN
# 658358           946123.0                           NaN       NaN       NaN
# 658359           619859.0                           NaN       NaN       NaN
# 658360                NaN                           NaN       NaN       NaN
# 658361            52212.0                           NaN       NaN       NaN
#
#         BuyerAgentAOR  ListAgentAOR  OriginatingSystemName  \
# 658357            NaN           NaN                    NaN
# 658358            NaN           NaN                    NaN
# 658359            NaN           NaN                    NaN
# 658360            NaN           NaN                    NaN
# 658361            NaN           NaN                    NaN
#
#        OriginatingSystemSubName
# 658357                      NaN
# 658358                      NaN
# 658359                      NaN
# 658360                      NaN
# 658361                      NaN
#
# [5 rows x 84 columns]

# %% [markdown]
# ### Overview of the dataset shape (Listing)

# %%
# checking the shape of the data
print(f"There are {sold_combined.shape[0]} rows and {sold_combined.shape[1]} columns in combined listing data.")  # f-string
# Out:
# There are 658362 rows and 84 columns in combined listing data.

# %% [markdown]
# ### Overview of the dataset shape (Sold)

# %%
# checking the shape of the data
print(f"There are {sold_combined.shape[0]} rows and {sold_combined.shape[1]} columns in Feb data.")  # f-string
# Out:
# There are 658362 rows and 84 columns in Feb data.

# %% [markdown]
# ### View Listing dataset columns

# %%
listing_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851298 entries, 0 to 851297
# Data columns (total 84 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   OriginalListPrice             847979 non-null  float64
#  1   ListingKey                    851298 non-null  int64
#  2   ListAgentEmail                778717 non-null  object
#  3   CloseDate                     267472 non-null  object
#  4   ClosePrice                    245327 non-null  float64
#  5   ListAgentFirstName            846325 non-null  object
#  6   ListAgentLastName             851219 non-null  object
#  7   Latitude                      739421 non-null  float64
#  8   Longitude                     740124 non-null  float64
#  9   UnparsedAddress               849175 non-null  object
#  10  PropertyType                  851298 non-null  object
#  11  LivingArea                    744957 non-null  float64
#  12  ListPrice                     849168 non-null  float64
#  13  DaysOnMarket                  851298 non-null  int64
#  14  ListOfficeName                851298 non-null  object
#  15  BuyerOfficeName               257219 non-null  object
#  16  CoListOfficeName              170681 non-null  object
#  17  ListAgentFullName             851067 non-null  object
#  18  CoListAgentFirstName          170046 non-null  object
#  19  CoListAgentLastName           170532 non-null  object
#  20  BuyerAgentMlsId               258898 non-null  object
#  21  BuyerAgentFirstName           258736 non-null  object
#  22  BuyerAgentLastName            259685 non-null  object
#  23  FireplacesTotal               0 non-null       float64
#  24  AssociationFeeFrequency       245707 non-null  object
#  25  AboveGradeFinishedArea        0 non-null       float64
#  26  ListingKeyNumeric             851298 non-null  int64
#  27  MLSAreaMajor                  755268 non-null  object
#  28  TaxAnnualAmount               6056 non-null    float64
#  29  CountyOrParish                851297 non-null  object
#  30  PropertyType.1                851298 non-null  object
#  31  MlsStatus                     851298 non-null  object
#  32  ElementarySchool              79167 non-null   object
#  33  ListAgentFirstName.1          846325 non-null  object
#  34  AttachedGarageYN              561191 non-null  object
#  35  ParkingTotal                  798952 non-null  float64
#  36  BuilderName                   29273 non-null   object
#  37  PropertySubType               747330 non-null  object
#  38  LotSizeAcres                  770129 non-null  float64
#  39  SubdivisionName               284555 non-null  object
#  40  BuyerOfficeAOR                244443 non-null  object
#  41  YearBuilt                     781907 non-null  float64
#  42  DaysOnMarket.1                851298 non-null  int64
#  43  StreetNumberNumeric           847566 non-null  float64
#  44  LivingArea.1                  744957 non-null  float64
#  45  ListingId                     851298 non-null  object
#  46  BathroomsTotalInteger         781396 non-null  float64
#  47  City                          850332 non-null  object
#  48  TaxYear                       870 non-null     float64
#  49  BuildingAreaTotal             136250 non-null  float64
#  50  BedroomsTotal                 748352 non-null  float64
#  51  ContractStatusChangeDate      844531 non-null  object
#  52  Longitude.1                   740124 non-null  float64
#  53  ElementarySchoolDistrict      0 non-null       float64
#  54  CoBuyerAgentFirstName         20769 non-null   object
#  55  PurchaseContractDate          377669 non-null  object
#  56  ListingContractDate           851298 non-null  object
#  57  BelowGradeFinishedArea        3418 non-null    float64
#  58  BusinessType                  5974 non-null    object
#  59  Latitude.1                    739421 non-null  float64
#  60  ListPrice.1                   849168 non-null  float64
#  61  StateOrProvince               851222 non-null  object
#  62  CoveredSpaces                 0 non-null       float64
#  63  MiddleOrJuniorSchool          79280 non-null   object
#  64  FireplaceYN                   728943 non-null  object
#  65  Stories                       631000 non-null  float64
#  66  HighSchool                    104237 non-null  object
#  67  Levels                        688238 non-null  object
#  68  ListAgentLastName.1           851219 non-null  object
#  69  CloseDate.1                   267472 non-null  object
#  70  LotSizeDimensions             48514 non-null   object
#  71  LotSizeArea                   773895 non-null  float64
#  72  MainLevelBedrooms             394562 non-null  float64
#  73  NewConstructionYN             736724 non-null  object
#  74  GarageSpaces                  689741 non-null  float64
#  75  HighSchoolDistrict            513073 non-null  object
#  76  PostalCode                    851089 non-null  object
#  77  BuyerOfficeName.1             257219 non-null  object
#  78  AssociationFee                576736 non-null  float64
#  79  LotSizeSquareFeet             772817 non-null  float64
#  80  MiddleOrJuniorSchoolDistrict  0 non-null       float64
#  81  UnparsedAddress.1             849175 non-null  object
#  82  BuyerAgencyCompensationType   123538 non-null  object
#  83  BuyerAgencyCompensation       123519 non-null  float64
# dtypes: float64(32), int64(4), object(48)
# memory usage: 545.6+ MB

# %% [markdown]
# ### View Sold dataset columns

# %%
sold_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 658362 entries, 0 to 658361
# Data columns (total 84 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Flooring                      386217 non-null  object
#  1   ViewYN                        592663 non-null  object
#  2   WaterfrontYN                  361 non-null     object
#  3   BasementYN                    10767 non-null   object
#  4   PoolPrivateYN                 574581 non-null  object
#  5   OriginalListPrice             656437 non-null  float64
#  6   ListingKey                    658362 non-null  int64
#  7   ListAgentEmail                614258 non-null  object
#  8   CloseDate                     658362 non-null  object
#  9   ClosePrice                    658355 non-null  float64
#  10  ListAgentFirstName            654430 non-null  object
#  11  ListAgentLastName             658290 non-null  object
#  12  Latitude                      639047 non-null  float64
#  13  Longitude                     639238 non-null  float64
#  14  UnparsedAddress               657332 non-null  object
#  15  PropertyType                  658362 non-null  object
#  16  LivingArea                    611430 non-null  float64
#  17  ListPrice                     657360 non-null  float64
#  18  DaysOnMarket                  658362 non-null  int64
#  19  ListOfficeName                658362 non-null  object
#  20  BuyerOfficeName               650108 non-null  object
#  21  CoListOfficeName              140192 non-null  object
#  22  ListAgentFullName             658189 non-null  object
#  23  CoListAgentFirstName          135379 non-null  object
#  24  CoListAgentLastName           135661 non-null  object
#  25  BuyerAgentMlsId               656400 non-null  object
#  26  BuyerAgentFirstName           655373 non-null  object
#  27  BuyerAgentLastName            657984 non-null  object
#  28  FireplacesTotal               0 non-null       float64
#  29  AssociationFeeFrequency       194952 non-null  object
#  30  AboveGradeFinishedArea        0 non-null       float64
#  31  ListingKeyNumeric             658362 non-null  int64
#  32  MLSAreaMajor                  586233 non-null  object
#  33  TaxAnnualAmount               2842 non-null    float64
#  34  CountyOrParish                658362 non-null  object
#  35  MlsStatus                     658362 non-null  object
#  36  ElementarySchool              73168 non-null   object
#  37  AttachedGarageYN              475867 non-null  object
#  38  ParkingTotal                  636779 non-null  float64
#  39  BuilderName                   25333 non-null   object
#  40  PropertySubType               607278 non-null  object
#  41  LotSizeAcres                  595429 non-null  float64
#  42  SubdivisionName               232217 non-null  object
#  43  BuyerOfficeAOR                630836 non-null  object
#  44  YearBuilt                     630247 non-null  float64
#  45  BuyerAgencyCompensationType   133531 non-null  object
#  46  StreetNumberNumeric           656695 non-null  float64
#  47  ListingId                     658362 non-null  object
#  48  BathroomsTotalInteger         627469 non-null  float64
#  49  City                          657846 non-null  object
#  50  BuyerAgencyCompensation       133596 non-null  float64
#  51  TaxYear                       413 non-null     float64
#  52  BuildingAreaTotal             84995 non-null   float64
#  53  BedroomsTotal                 614019 non-null  float64
#  54  ContractStatusChangeDate      656933 non-null  object
#  55  ElementarySchoolDistrict      0 non-null       float64
#  56  CoBuyerAgentFirstName         53432 non-null   object
#  57  PurchaseContractDate          645258 non-null  object
#  58  ListingContractDate           658268 non-null  object
#  59  BelowGradeFinishedArea        2817 non-null    float64
#  60  BusinessType                  1847 non-null    object
#  61  StateOrProvince               658362 non-null  object
#  62  CoveredSpaces                 0 non-null       float64
#  63  MiddleOrJuniorSchool          73698 non-null   object
#  64  FireplaceYN                   600209 non-null  object
#  65  Stories                       525101 non-null  float64
#  66  HighSchool                    95936 non-null   object
#  67  Levels                        566302 non-null  object
#  68  LotSizeDimensions             34353 non-null   object
#  69  LotSizeArea                   597522 non-null  float64
#  70  MainLevelBedrooms             348375 non-null  float64
#  71  NewConstructionYN             580050 non-null  object
#  72  GarageSpaces                  573803 non-null  float64
#  73  HighSchoolDistrict            438967 non-null  object
#  74  PostalCode                    658177 non-null  object
#  75  AssociationFee                454281 non-null  float64
#  76  LotSizeSquareFeet             597007 non-null  float64
#  77  MiddleOrJuniorSchoolDistrict  0 non-null       float64
#  78  latfilled                     161667 non-null  object
#  79  lonfilled                     161667 non-null  object
#  80  BuyerAgentAOR                 519693 non-null  object
#  81  ListAgentAOR                  524439 non-null  object
#  82  OriginatingSystemName         77869 non-null   object
#  83  OriginatingSystemSubName      77869 non-null   object
# dtypes: float64(28), int64(3), object(53)
# memory usage: 421.9+ MB

# %% [markdown]
# ### View column counts (Listing)

# %%
listing_combined.PropertyType.value_counts()
# Out:
# PropertyType
# Residential            539213
# ResidentialLease       177543
# Land                    56333
# ResidentialIncome       31571
# ManufacturedInPark      24483
# CommercialSale          11696
# CommercialLease          7725
# BusinessOpportunity      2734
# Name: count, dtype: int64

# %% [markdown]
# ### View column counts (Sold)

# %%
sold_combined.PropertyType.value_counts()
# Out:
# PropertyType
# Residential            442285
# ResidentialLease       150415
# Land                    21927
# ManufacturedInPark      18004
# ResidentialIncome       17628
# CommercialSale           4147
# CommercialLease          3494
# BusinessOpportunity       462
# Name: count, dtype: int64

# %% [markdown]
# ### Filter PropertyType to Residential only
# We’re filtering the dataset to only include residential properties so we can analyze the deals that actually matter to us.

# %% [markdown]
# ### Create new datasets

# %%
listing_residential_df = listing_combined[listing_combined["PropertyType"] == "Residential"]
sold_residential_df = sold_combined[sold_combined["PropertyType"] == "Residential"]

# %% [markdown]
# ### Show row and column counts after the Residential filter

# %%
# checking the shape of the data
print(f"There are {listing_residential_df.shape[0]} rows and {listing_residential_df.shape[1]} columns in listing data for residential only.")  # f-string
print(f"There are {sold_residential_df.shape[0]} rows and {sold_residential_df.shape[1]} columns in sold data for residential only.")  # f-string
# Out:
# There are 539213 rows and 84 columns in listing data for residential only.
# There are 442285 rows and 84 columns in sold data for residential only.

# %% [markdown]
# ### Save new datasets to CSVs (residential only)

# %%
listing_residential_df.to_csv(save_path / "listings_residential_properties.csv", index=False)
sold_residential_df.to_csv(save_path / "sold_residential_properties.csv", index=False)

# %% [markdown]
# ## Week 2-3 – Data Structuring and Validation
# Before analytics begins, the dataset must be inspected and filtered to ensure only relevant residential
# property records are used.

# %% [markdown]
# ### TO DO:
# - Separate market analysis fields from metadata fields
# - Decide which columns to drop vs. retain (keep core fields even if partially missing)
# - Numeric Distribution Review: Analyze the distribution of key numeric fields: ClosePrice, ListPrice, OriginalListPrice, LivingArea,
# LotSizeAcres, BedroomsTotal, BathroomsTotalInteger, DaysOnMarket, and YearBuilt. For each field,
# generate histograms, boxplots, and percentile summaries, and identify extreme outliers for later handling.
# -  Produce a numeric distribution summary (min, max, mean, median, percentiles) for ClosePrice, LivingArea, and
# DaysOnMarket.
# - Save the filtered dataset as a new CSV.

# %% [markdown]
# ### Listing

# %%
listing_residential_df.shape
# Out:
# (442285, 84)

# %%
listing_residential_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 539213 entries, 0 to 851297
# Data columns (total 84 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   OriginalListPrice             538439 non-null  float64
#  1   ListingKey                    539213 non-null  int64
#  2   ListAgentEmail                492217 non-null  object
#  3   CloseDate                     170010 non-null  object
#  4   ClosePrice                    150192 non-null  float64
#  5   ListAgentFirstName            535007 non-null  object
#  6   ListAgentLastName             539172 non-null  object
#  7   Latitude                      459090 non-null  float64
#  8   Longitude                     459090 non-null  float64
#  9   UnparsedAddress               538548 non-null  object
#  10  PropertyType                  539213 non-null  object
#  11  LivingArea                    538659 non-null  float64
#  12  ListPrice                     539213 non-null  float64
#  13  DaysOnMarket                  539213 non-null  int64
#  14  ListOfficeName                539213 non-null  object
#  15  BuyerOfficeName               161211 non-null  object
#  16  CoListOfficeName              120832 non-null  object
#  17  ListAgentFullName             539121 non-null  object
#  18  CoListAgentFirstName          120340 non-null  object
#  19  CoListAgentLastName           120740 non-null  object
#  20  BuyerAgentMlsId               163411 non-null  object
#  21  BuyerAgentFirstName           162783 non-null  object
#  22  BuyerAgentLastName            163526 non-null  object
#  23  FireplacesTotal               0 non-null       float64
#  24  AssociationFeeFrequency       230397 non-null  object
#  25  AboveGradeFinishedArea        0 non-null       float64
#  26  ListingKeyNumeric             539213 non-null  int64
#  27  MLSAreaMajor                  466342 non-null  object
#  28  TaxAnnualAmount               0 non-null       float64
#  29  CountyOrParish                539213 non-null  object
#  30  PropertyType.1                539213 non-null  object
#  31  MlsStatus                     539213 non-null  object
#  32  ElementarySchool              64272 non-null   object
#  33  ListAgentFirstName.1          535007 non-null  object
#  34  AttachedGarageYN              445031 non-null  object
#  35  ParkingTotal                  539193 non-null  float64
#  36  BuilderName                   25203 non-null   object
#  37  PropertySubType               537973 non-null  object
#  38  LotSizeAcres                  494864 non-null  float64
#  39  SubdivisionName               198698 non-null  object
#  40  BuyerOfficeAOR                150517 non-null  object
#  41  YearBuilt                     538281 non-null  float64
#  42  DaysOnMarket.1                539213 non-null  int64
#  43  StreetNumberNumeric           538368 non-null  float64
#  44  LivingArea.1                  538659 non-null  float64
#  45  ListingId                     539213 non-null  object
#  46  BathroomsTotalInteger         539158 non-null  float64
#  47  City                          538632 non-null  object
#  48  TaxYear                       0 non-null       float64
#  49  BuildingAreaTotal             47829 non-null   float64
#  50  BedroomsTotal                 539067 non-null  float64
#  51  ContractStatusChangeDate      533271 non-null  object
#  52  Longitude.1                   459090 non-null  float64
#  53  ElementarySchoolDistrict      0 non-null       float64
#  54  CoBuyerAgentFirstName         14884 non-null   object
#  55  PurchaseContractDate          269602 non-null  object
#  56  ListingContractDate           539213 non-null  object
#  57  BelowGradeFinishedArea        3022 non-null    float64
#  58  BusinessType                  0 non-null       object
#  59  Latitude.1                    459090 non-null  float64
#  60  ListPrice.1                   539213 non-null  float64
#  61  StateOrProvince               539150 non-null  object
#  62  CoveredSpaces                 0 non-null       float64
#  63  MiddleOrJuniorSchool          64419 non-null   object
#  64  FireplaceYN                   538640 non-null  object
#  65  Stories                       445371 non-null  float64
#  66  HighSchool                    84397 non-null   object
#  67  Levels                        481509 non-null  object
#  68  ListAgentLastName.1           539172 non-null  object
#  69  CloseDate.1                   170010 non-null  object
#  70  LotSizeDimensions             28131 non-null   object
#  71  LotSizeArea                   495703 non-null  float64
#  72  MainLevelBedrooms             293890 non-null  float64
#  73  NewConstructionYN             502070 non-null  object
#  74  GarageSpaces                  509327 non-null  float64
#  75  HighSchoolDistrict            377192 non-null  object
#  76  PostalCode                    539200 non-null  object
#  77  BuyerOfficeName.1             161211 non-null  object
#  78  AssociationFee                409916 non-null  float64
#  79  LotSizeSquareFeet             495529 non-null  float64
#  80  MiddleOrJuniorSchoolDistrict  0 non-null       float64
#  81  UnparsedAddress.1             538548 non-null  object
#  82  BuyerAgencyCompensationType   79013 non-null   object
#  83  BuyerAgencyCompensation       78993 non-null   float64
# dtypes: float64(32), int64(4), object(48)
# memory usage: 349.7+ MB

# %%
# Null count + percentage summary
null_summary_listing = pd.DataFrame({
    "Null Count": listing_residential_df.isna().sum(),
    "Missing %": listing_residential_df.isna().mean() * 100
})

# Sort by highest missing %
null_summary_listing = null_summary_listing.sort_values(by="Missing %", ascending=False)

print(null_summary_listing.head(20))
# Out:
#                               Null Count   Missing %
# TaxAnnualAmount                   539213  100.000000
# FireplacesTotal                   539213  100.000000
# ElementarySchoolDistrict          539213  100.000000
# BusinessType                      539213  100.000000
# TaxYear                           539213  100.000000
# CoveredSpaces                     539213  100.000000
# MiddleOrJuniorSchoolDistrict      539213  100.000000
# AboveGradeFinishedArea            539213  100.000000
# BelowGradeFinishedArea            536191   99.439554
# CoBuyerAgentFirstName             524329   97.239681
# BuilderName                       514010   95.325966
# LotSizeDimensions                 511082   94.782952
# BuildingAreaTotal                 491384   91.129850
# ElementarySchool                  474941   88.080406
# MiddleOrJuniorSchool              474794   88.053144
# BuyerAgencyCompensation           460220   85.350316
# BuyerAgencyCompensationType       460200   85.346607
# HighSchool                        454816   84.348115
# CoListAgentFirstName              418873   77.682289
# CoListAgentLastName               418473   77.608107

# %%
# Identify high-missing columns above 90%
high_missing_90 = (
    listing_residential_df.isna()
    .mean()
    .mul(100)
    .loc[lambda x: x > 90]
    .sort_values(ascending=False)
)

print(high_missing_90)
# Out:
# FireplacesTotal                 100.000000
# AboveGradeFinishedArea          100.000000
# TaxAnnualAmount                 100.000000
# TaxYear                         100.000000
# ElementarySchoolDistrict        100.000000
# BusinessType                    100.000000
# CoveredSpaces                   100.000000
# MiddleOrJuniorSchoolDistrict    100.000000
# BelowGradeFinishedArea           99.439554
# CoBuyerAgentFirstName            97.239681
# BuilderName                      95.325966
# LotSizeDimensions                94.782952
# BuildingAreaTotal                91.129850
# dtype: float64

# %% [markdown]
# ### Sold

# %%
sold_residential_df.shape
# Out:
# (442285, 84)

# %%
sold_residential_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 442285 entries, 2 to 658356
# Data columns (total 84 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Flooring                      283222 non-null  object
#  1   ViewYN                        404876 non-null  object
#  2   WaterfrontYN                  278 non-null     object
#  3   BasementYN                    8573 non-null    object
#  4   PoolPrivateYN                 403448 non-null  object
#  5   OriginalListPrice             441461 non-null  float64
#  6   ListingKey                    442285 non-null  int64
#  7   ListAgentEmail                413215 non-null  object
#  8   CloseDate                     442285 non-null  object
#  9   ClosePrice                    442283 non-null  float64
#  10  ListAgentFirstName            438867 non-null  object
#  11  ListAgentLastName             442239 non-null  object
#  12  Latitude                      426309 non-null  float64
#  13  Longitude                     426309 non-null  float64
#  14  UnparsedAddress               441875 non-null  object
#  15  PropertyType                  442285 non-null  object
#  16  LivingArea                    442036 non-null  float64
#  17  ListPrice                     442285 non-null  float64
#  18  DaysOnMarket                  442285 non-null  int64
#  19  ListOfficeName                442285 non-null  object
#  20  BuyerOfficeName               434941 non-null  object
#  21  CoListOfficeName              103929 non-null  object
#  22  ListAgentFullName             442194 non-null  object
#  23  CoListAgentFirstName          100758 non-null  object
#  24  CoListAgentLastName           101018 non-null  object
#  25  BuyerAgentMlsId               441745 non-null  object
#  26  BuyerAgentFirstName           440077 non-null  object
#  27  BuyerAgentLastName            442100 non-null  object
#  28  FireplacesTotal               0 non-null       float64
#  29  AssociationFeeFrequency       184515 non-null  object
#  30  AboveGradeFinishedArea        0 non-null       float64
#  31  ListingKeyNumeric             442285 non-null  int64
#  32  MLSAreaMajor                  383537 non-null  object
#  33  TaxAnnualAmount               0 non-null       float64
#  34  CountyOrParish                442285 non-null  object
#  35  MlsStatus                     442285 non-null  object
#  36  ElementarySchool              59018 non-null   object
#  37  AttachedGarageYN              374819 non-null  object
#  38  ParkingTotal                  441431 non-null  float64
#  39  BuilderName                   21917 non-null   object
#  40  PropertySubType               441440 non-null  object
#  41  LotSizeAcres                  407041 non-null  float64
#  42  SubdivisionName               164314 non-null  object
#  43  BuyerOfficeAOR                419129 non-null  object
#  44  YearBuilt                     441896 non-null  float64
#  45  BuyerAgencyCompensationType   90403 non-null   object
#  46  StreetNumberNumeric           441786 non-null  float64
#  47  ListingId                     442285 non-null  object
#  48  BathroomsTotalInteger         442205 non-null  float64
#  49  City                          441925 non-null  object
#  50  BuyerAgencyCompensation       90381 non-null   float64
#  51  TaxYear                       0 non-null       float64
#  52  BuildingAreaTotal             30803 non-null   float64
#  53  BedroomsTotal                 442273 non-null  float64
#  54  ContractStatusChangeDate      441102 non-null  object
#  55  ElementarySchoolDistrict      0 non-null       float64
#  56  CoBuyerAgentFirstName         40088 non-null   object
#  57  PurchaseContractDate          442087 non-null  object
#  58  ListingContractDate           442284 non-null  object
#  59  BelowGradeFinishedArea        2482 non-null    float64
#  60  BusinessType                  0 non-null       object
#  61  StateOrProvince               442285 non-null  object
#  62  CoveredSpaces                 0 non-null       float64
#  63  MiddleOrJuniorSchool          59452 non-null   object
#  64  FireplaceYN                   441948 non-null  object
#  65  Stories                       373103 non-null  float64
#  66  HighSchool                    77064 non-null   object
#  67  Levels                        398612 non-null  object
#  68  LotSizeDimensions             21353 non-null   object
#  69  LotSizeArea                   407588 non-null  float64
#  70  MainLevelBedrooms             256232 non-null  float64
#  71  NewConstructionYN             409609 non-null  object
#  72  GarageSpaces                  423367 non-null  float64
#  73  HighSchoolDistrict            321551 non-null  object
#  74  PostalCode                    442283 non-null  object
#  75  AssociationFee                341052 non-null  float64
#  76  LotSizeSquareFeet             407456 non-null  float64
#  77  MiddleOrJuniorSchoolDistrict  0 non-null       float64
#  78  latfilled                     108157 non-null  object
#  79  lonfilled                     108157 non-null  object
#  80  BuyerAgentAOR                 347940 non-null  object
#  81  ListAgentAOR                  351826 non-null  object
#  82  OriginatingSystemName         49744 non-null   object
#  83  OriginatingSystemSubName      49744 non-null   object
# dtypes: float64(28), int64(3), object(53)
# memory usage: 286.8+ MB

# %%
# Null count + percentage summary
null_summary_sold = pd.DataFrame({
    "Null Count": sold_residential_df.isna().sum(),
    "Missing %": sold_residential_df.isna().mean() * 100
})

# Sort by highest missing %
null_summary_sold = null_summary_sold.sort_values(by="Missing %", ascending=False)

print(null_summary_sold)
# Out:
#                           Null Count  Missing %
# AboveGradeFinishedArea        442285      100.0
# CoveredSpaces                 442285      100.0
# TaxAnnualAmount               442285      100.0
# TaxYear                       442285      100.0
# ElementarySchoolDistrict      442285      100.0
# ...                              ...        ...
# CloseDate                          0        0.0
# MlsStatus                          0        0.0
# CountyOrParish                     0        0.0
# ListingKeyNumeric                  0        0.0
# ListingId                          0        0.0
#
# [84 rows x 2 columns]

# %%
# Identify high-missing columns above 90%
high_missing_90_sold = (
    sold_residential_df.isna()
    .mean()
    .mul(100)
    .loc[lambda x: x > 90]
    .sort_values(ascending=False)
)

print(high_missing_90_sold)
# Out:
# FireplacesTotal                 100.000000
# AboveGradeFinishedArea          100.000000
# TaxAnnualAmount                 100.000000
# TaxYear                         100.000000
# ElementarySchoolDistrict        100.000000
# BusinessType                    100.000000
# CoveredSpaces                   100.000000
# MiddleOrJuniorSchoolDistrict    100.000000
# WaterfrontYN                     99.937145
# BelowGradeFinishedArea           99.438823
# BasementYN                       98.061657
# LotSizeDimensions                95.172118
# BuilderName                      95.044598
# BuildingAreaTotal                93.035486
# CoBuyerAgentFirstName            90.936161
# dtype: float64

# %% [markdown]
# ### Suggested Intern Questions

# %%
# What is the Residential vs. other property type share?
# Need to used orginal listing_combined to get the full picture of all property types, not just residential
property_summary = (
    listing_combined['PropertyType']
    .value_counts(normalize=True)
    .mul(100)
    .round(2)
)
print(property_summary)
# Out:
# PropertyType
# Residential            63.34
# ResidentialLease       20.86
# Land                    6.62
# ResidentialIncome       3.71
# ManufacturedInPark      2.88
# CommercialSale          1.37
# CommercialLease         0.91
# BusinessOpportunity     0.32
# Name: proportion, dtype: float64

# %%
# What are the median and average close prices?
median_price = round(sold_residential_df['ClosePrice'].median(), 2)
mean_price = round(sold_residential_df['ClosePrice'].mean(), 2)

print("Median Close Price:", median_price)
print("Average Close Price:", mean_price)
# Out:
# Median Close Price: 820000.0
# Average Close Price: 1175902.21

# %%
# What does the Days on Market distribution look like?

sold_residential_df['DaysOnMarket'].plot(kind='hist', bins=50)
plt.title("Days on Market Distribution")
plt.xlabel("Days on Market")
plt.ylabel("Frequency")
plt.show()

# %%
sold_residential_df['DaysOnMarket'].describe()
# Out:
# count    442285.000000
# mean         36.885874
# std          52.919810
# min        -288.000000
# 25%           8.000000
# 50%          18.000000
# 75%          48.000000
# max       12430.000000
# Name: DaysOnMarket, dtype: float64

# %%
# Removing outliers by capping at 200 days on market to see the distribution more clearly
sold_residential_df['DaysOnMarket'].clip(upper=200).plot(kind='hist', bins=50)
plt.title("Days on Market Distribution (Capped at 200)")
plt.show()

# %% [markdown]
# The distribution of Days on Market is right-skewed, with most properties selling within a relatively short time frame. The median is lower than the mean, indicating the presence of outliers where some properties remain on the market significantly longer.
# - Most homes sell quickly
# - A few take much longer thus a skew
# - The market is not evenly distributed

# %%
# What percentage of homes sold above vs. below list price?
sdf = sold_residential_df

sdf['Above_List'] = sdf['ClosePrice'] > sdf['ListPrice']

# calculate the percentage of homes sold above vs. below list price
price_comparison = sdf['Above_List'].value_counts(normalize=True) * 100

print(price_comparison)

# ~41% of homes sold above list price, while ~59% sold at or below list price.
# Out:
# Above_List
# False    59.283268
# True     40.716732
# Name: proportion, dtype: float64

# %%
# Are there any apparent date consistency issues (e.g., close date before listing date)?

# We can check for date consistency by comparing the 'CloseDate' and 'ListDate' columns. If there are any rows where 'CloseDate' is before 'ListDate', that would indicate a potential issue.
sdf['CloseDate'] = pd.to_datetime(sdf['CloseDate'], errors='coerce')
sdf['ListingContractDate'] = pd.to_datetime(sdf['ListingContractDate'], errors='coerce') 

date_issues = sdf[sdf['CloseDate'] < sdf['ListingContractDate']]

print("Number of inconsistent records:", len(date_issues))
# Out:
# Number of inconsistent records: 63

# %%
date_issues[['ListingContractDate', 'CloseDate']].head()
# Out:
#       ListingContractDate  CloseDate
# 28878          2024-10-02 2024-09-19
# 29179          2024-09-30 2024-09-05
# 30015          2024-09-28 2024-09-24
# 46444          2024-08-14 2024-08-13
# 70629          2025-01-24 2025-01-23

# %%
# percentage
date_issue_percentage = (len(date_issues) / len(sdf)) * 100
print(f"Percentage of date consistency issues: {date_issue_percentage:.2f}%")
# Out:
# Percentage of date consistency issues: 0.01%

# %% [markdown]
# A small number of records were identified where the close date precedes the listing date, indicating potential data entry or system errors. These records were flagged for further review or removal. Small % indicates normal data noise.

# %%
# Which counties have the highest median prices?

# group by county, calculate median close price, and sort in descending order
county_median = (
    sdf.groupby('CountyOrParish')['ClosePrice']
    .median()
    .sort_values(ascending=False)
)

print(county_median.head(10))
# Out:
# CountyOrParish
# Del Norte        2485000.0
# San Mateo        1700000.0
# Santa Clara      1600000.0
# Santa Cruz       1199000.0
# San Francisco    1180000.0
# Marin            1175000.0
# Orange           1170000.0
# Alameda          1140000.0
# Alpine           1100000.0
# Mono              915000.0
# Name: ClosePrice, dtype: float64

# %%
# Table format for better readability
county_median_df = county_median.reset_index()
county_median_df.columns = ['County', 'Median Close Price']

print(county_median_df.head(10))
# Out:
#           County  Median Close Price
# 0      Del Norte           2485000.0
# 1      San Mateo           1700000.0
# 2    Santa Clara           1600000.0
# 3     Santa Cruz           1199000.0
# 4  San Francisco           1180000.0
# 5          Marin           1175000.0
# 6         Orange           1170000.0
# 7        Alameda           1140000.0
# 8         Alpine           1100000.0
# 9           Mono            915000.0

# %%
county_median.head(10).plot(kind='bar')
plt.title("Top 10 Counties by Median Close Price")
plt.ylabel("Median Price")
plt.xticks(rotation=45)
plt.show()
